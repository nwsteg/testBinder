# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # Import the 3D plotting toolkit
import pandas as pd

# Define the structure of your DataFrame with appropriate columns
columns = ['Paper #', 'Label', 'ypd99','d99[mm]','vstar[m/s]','rw[kg/m3]','muw[Pa.s]']
dtypes = {'Paper #': int, 'Label': str, 'ypd99': float, 'd99[mm]': float, 'vstar[m/s]': float, 'rw[kg/m3]': float, 'muw[Pa.s]': float}
df = pd.DataFrame(columns=columns).astype(dtypes)

paper_data = pd.DataFrame({
    'Paper #': [1],
    'Label': ['Semper 2013'],
    'ypd99': [130],
    'd99[mm]': [14],
    'vstar[m/s]': [56],
    'rw[kg/m3]': [0.00365],
    'muw[Pa.s]': [2.23E-05]
})
df = pd.concat([df, paper_data], ignore_index=True)

paper_data = pd.DataFrame({
    'Paper #': [2],
    'Label': ['Neeb 2018'],
    'ypd99': [336],
    'd99[mm]': [4],
    'vstar[m/s]': [49.1],
    'rw[kg/m3]': [0.0284],
    'muw[Pa.s]': [2.03E-05]
})
df = pd.concat([df, paper_data], ignore_index=True)

paper_data = pd.DataFrame({
    'Paper #': [3],
    'Label': ['Kocher 2018'],
    'ypd99': [4088],
    'd99[mm]': [11],
    'vstar[m/s]': [18.7],
    'rw[kg/m3]': [0.34],
    'muw[Pa.s]': [1.71E-05]
})
df = pd.concat([df, paper_data], ignore_index=True)

paper_data = pd.DataFrame({
    'Paper #': [4],
    'Label': ['Zahradka 2016 BL1'],
    'ypd99': [156],
    'd99[mm]': [12],
    'vstar[m/s]': [36.7],
    'rw[kg/m3]': [0.0063],
    'muw[Pa.s]': [1.77E-05]
})
df = pd.concat([df, paper_data], ignore_index=True)

paper_data = pd.DataFrame({
    'Paper #': [5],
    'Label': ['Zahradka 2016 BL2'],
    'ypd99': [362],
    'd99[mm]': [9.7],
    'vstar[m/s]': [31.9],
    'rw[kg/m3]': [0.0208],
    'muw[Pa.s]': [1.77E-05]
})
df = pd.concat([df, paper_data], ignore_index=True)

paper_data = pd.DataFrame({
    'Paper #': [6],
    'Label': ['Peltier 2016'],
    'ypd99': [1140],
    'd99[mm]': [10.9],
    'vstar[m/s]': [35],
    'rw[kg/m3]': [0.0566],
    'muw[Pa.s]': [1.894E-05]
})
df = pd.concat([df, paper_data], ignore_index=True)

paper_data = pd.DataFrame({
    'Paper #': [7],
    'Label': ['Ekoto 2009'],
    'ypd99': [3770],
    'd99[mm]': [11],
    'vstar[m/s]': [23],
    'rw[kg/m3]': [0.271],
    'muw[Pa.s]': [1.82E-05]
})
df = pd.concat([df, paper_data], ignore_index=True)

paper_data = pd.DataFrame({
    'Paper #': [8],
    'Label': ['Gragston 2022'],
    'ypd99': [3500],
    'd99[mm]': [50],
    'vstar[m/s]': [33.5],
    'rw[kg/m3]': [0.035],
    'muw[Pa.s]': [1.82E-05]
})
df = pd.concat([df, paper_data], ignore_index=True)

paper_data = pd.DataFrame({
    'Paper #': [9],
    'Label': ['E-FST393 FPS'],
    'ypd99': [80],
    'd99[mm]': [2.6],
    'vstar[m/s]': [58],
    'rw[kg/m3]': [0.00596],
    'muw[Pa.s]': [1.814E-05]
})
df = pd.concat([df, paper_data], ignore_index=True)

paper_data = pd.DataFrame({
    'Paper #': [10],
    'Label': ['K-FST487 FPS'],
    'ypd99': [74.7],
    'd99[mm]': [3],
    'vstar[m/s]': [68],
    'rw[kg/m3]': [0.0013],
    'muw[Pa.s]': [1.814E-05]
})
df = pd.concat([df, paper_data], ignore_index=True)

# Sort the DataFrame by the 'Custom Metric' column in descending order
df['Custom Metric'] = df['rw[kg/m3]'] * (df['d99[mm]'] / 1000)
df_sorted = df.sort_values('Custom Metric', ascending=False)

datapath='data_bl/'
bls=[]
bls.append(np.genfromtxt(datapath+'compare_literature_bl_scaled_semper.csv', delimiter=',', usecols=(0, 1), dtype=float))
bls.append(np.genfromtxt(datapath+'compare_literature_bl_scaled_neeb.csv', delimiter=',', usecols=(0, 1), dtype=float))
bls.append(np.genfromtxt(datapath+'compare_literature_bl_scaled_kocher.csv', delimiter=',', usecols=(0, 1), dtype=float))
bls.append(np.genfromtxt(datapath+'compare_literature_bl_scaled_zahdraka_Re800.csv', delimiter=',', usecols=(0, 1), dtype=float))
bls.append(np.genfromtxt(datapath+'compare_literature_bl_scaled_zahdraka_Re2400.csv', delimiter=',', usecols=(0, 1), dtype=float))
bls.append(np.genfromtxt(datapath+'compare_literature_bl_scaled_peltier.csv', delimiter=',', usecols=(0, 1), dtype=float))
bls.append(np.genfromtxt(datapath+'compare_literature_bl_scaled_ekoto.csv', delimiter=',', usecols=(0, 1), dtype=float))
bls.append(np.genfromtxt(datapath+'compare_literature_bl_scaled_gragston.csv', delimiter=',', usecols=(0, 1), dtype=float))
bls.append(np.genfromtxt(datapath+'compare_literature_bl_scaled_hoffman.csv', delimiter=',', usecols=(0, 1), dtype=float))
bls.append(np.genfromtxt(datapath+'compare_literature_bl_scaled_posladek.csv', delimiter=',', usecols=(0, 1), dtype=float))
bls[4][:,1]=bls[4][:,1]-6

# Sample markers and colors, expand as needed
markers = ['o', 's', 'D', '^', 'v', '>', '<', 'p', '*', 'h']
colors = ['brown', 'g', 'grey', 'c', 'm', 'y', 'k', 'orange', 'r', 'b']

# Create a 3D plot
fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, projection='3d')

# Iterate through sorted data
for (idx, row), marker, color in zip(df_sorted.iterrows(), markers, colors):
    id = int(row['Paper #'] - 1)
    try:
        bl = bls[id]  # Get boundary layer data for the current paper
        # Plot in 3D with the new axis arrangement
        ax.plot(np.log(bl[:,0]), bl[:,1], zs=np.log(row['Custom Metric']), zdir='z', linestyle='', marker=marker, 
                mec=color, mfc=(1, 1, 1, 0), label=row['Label'])
    except:
        pass

# Set labels for the axes
ax.set_ylabel(r'$u^+_{VD}$')
ax.set_xlabel(r'$\log(y^+)$')
ax.set_zlabel(r'$\log(\rho_w \delta_{99})$')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
